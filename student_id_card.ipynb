# %% [markdown]
# <a href="https://colab.research.google.com/github/saranyaece30111998-analyst/Python-Fundamentals/blob/main/student_id_card.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Case Study – Student ID Card Generator Instructions:
#
# • Create variables: student_name, roll_number, department
#
# • Take input from the user using input() function
#
# • Convert student_name and department into uppercase using upper()
#
# • Extract first 4 letters of student_name and department using slicing
#
# • Create Student ID by combining name, department, and roll number
#
# • Display Name, Department, Roll Number, and Student ID only
#
# • Use print() and f-string for output display """

# %%
# Create variables
student_name = input("Enter your name: ")
roll_number = input("Enter your roll number: ")
department = input("Enter your department: ")

# Convert student_name and department into uppercase using upper()
student_name = student_name.upper()
department = department.upper()

# Extract first 4 letters of student_name and department using slicing
Name= student_name[0:4]
Dept=department[0:4]

# Create Student ID by combining name, department, and roll number
studentid = student_name + "-" + department+ "-" + roll_number

# Display Name, Department, Roll Number, and Student ID only
print(f"Student Name: {student_name}")
print(f"Roll Number: {roll_number}")
print(f"Department: {department}")
print(f"Student ID: {studentid}")
# Out:
# Enter your name: saranya
# Enter your roll number: 27
# Enter your department: ece
# Student Name: SARANYA
# Roll Number: 27
# Department: ECE
# Student ID: SARANYA-ECE-27
